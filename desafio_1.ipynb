# %%
import pandas as pd

# %% [markdown]
# #### Lectura de archivos Excel
#
# Archivo: aportes_elecciones_2017

# %%
df_aportes_elecciones = pd.read_excel("input/aportes_elecciones_2017.xlsx")
df_aportes_elecciones
# Out:
#                              NOMBRE APORTANTE   TIPO APORTANTE  \
# 0        SEBASTIAN IGNACIO CASTILLO FERNANDEZ  PERSONA NATURAL
# 1                 LUIS EUJENIO MANDIOLA SOLAR  PERSONA NATURAL
# 2                     ANA MARIA LAGOS HERRERA  PERSONA NATURAL
# 3      MARCO ANTONIO ENRIQUEZ-OMINAMI GUMUCIO  PERSONA NATURAL
# 4                                         NaN  PERSONA NATURAL
# ...                                       ...              ...
# 14928                                     NaN              NaN
# 14929                                     NaN              NaN
# 14930                                     NaN              NaN
# 14931                                     NaN              NaN
# 14932                                     NaN              NaN
#
#       NOMBRE CANDIDATO/PARTIDO POLITICO TIPO DONATARIO               ELECCION  \
# 0            ALEJANDRO GUILLIER ALVAREZ      CANDIDATO             PRESIDENTE
# ...

# %% [markdown]
# ##### Lectura de archivos CSV

# %%
## Archivo de accidentes aereos

df_airplane_crashes = pd.read_csv('input/airplane_crashes_since_1908.csv')
df_airplane_crashes
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# ...

# %%
## CRM

df_crm = pd.read_csv("input/crm.csv")
df_crm
# Out:
#           sales_agent           manager regional_office   status     account  \
# 0       Anna Snelling  Dustin Brinkmann         Central  Current         NaN
# 1       Anna Snelling  Dustin Brinkmann         Central  Current         NaN
# 2       Anna Snelling  Dustin Brinkmann         Central  Current         NaN
# 3       Anna Snelling  Dustin Brinkmann         Central  Current         NaN
# 4       Anna Snelling  Dustin Brinkmann         Central  Current         NaN
# ...               ...               ...             ...      ...         ...
# 8795  Maureen Marcano     Summer Sewald            West  Current  Green-Plus
# 8796  Maureen Marcano     Summer Sewald            West  Current      Finjob
# 8797  Maureen Marcano     Summer Sewald            West  Current    Labdrill
# 8798  Maureen Marcano     Summer Sewald            West  Current   Ganjaflex
# 8799  Maureen Marcano     Summer Sewald            West  Current      Sonron
#
# ...
